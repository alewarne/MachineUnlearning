# %% [markdown]
# # Backdoor Unlearning
#
# ## Outline
#
# 1. Experimental setup (generating configs)
# 2. Clean model training
# 3. Poisoned model training
# 4. First-order unlearning
# 5. Second-order unlearning
# 6. Visualizing results

# %% [markdown]
# ## Experimental Setup
#
# - All configurations to test are defined in the `[train|poison|unlearn].json` files (see below).
# - If parameters are passed as list, all their combinations are tested in a grid-search manner.
# - Only a single combination is provided for this demo. The original combinations are in `Applications/Poisoning/configs`
# - The function generates directories and configuration files for each combination. They are later used by an evaluation script to run the experiment. This allows for parallelization and distributed execution.

# %%
import sys
sys.path.append('../')

# %%
# only if you are using CUDA devices
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
from conf import BASE_DIR
from Applications.Poisoning.gen_configs import main as gen_configs

model_folder = BASE_DIR/'models'/'poisoning'
train_conf = BASE_DIR/'Applications'/'Poisoning'/'configs'/'demo'/'train.json'
poison_conf = BASE_DIR/'Applications'/'Poisoning'/'configs'/'demo'/'poison.json'
unlearn_conf = BASE_DIR/'Applications'/'Poisoning'/'configs'/'demo'/'unlearn.json'

gen_configs(model_folder, train_conf, poison_conf, unlearn_conf)

# %% [markdown]
# ## Clean Model Training
#
# - Train a clean model for reference.

# %%
from Applications.Poisoning.train import main as train

# train one clean and one poisoned model
train(model_folder=model_folder/'clean')
# Out:
# 2023-04-20 14:57:48.526304: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 14:57:49.147176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9648 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:20:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (BatchN  (None, 32, 32, 128)      512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_2 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,800,842
# Trainable params: 1,798,282
# Non-trainable params: 2,560
# _________________________________________________________________
# None
# Epoch 1/100
# 2023-04-20 14:57:51.483437: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8400
# 2023-04-20 14:57:52.165969: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 782/782 [==============================] - 16s 16ms/step - loss: 1.2870 - accuracy: 0.5508 - val_loss: 0.9092 - val_accuracy: 0.6768
# Epoch 2/100
# 782/782 [==============================] - 12s 15ms/step - loss: 0.7779 - accuracy: 0.7277 - val_loss: 0.7920 - val_accuracy: 0.7234
# Epoch 3/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.5916 - accuracy: 0.7933 - val_loss: 0.6781 - val_accuracy: 0.7602
# Epoch 4/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.4691 - accuracy: 0.8361 - val_loss: 0.5774 - val_accuracy: 0.8032
# Epoch 5/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.3751 - accuracy: 0.8671 - val_loss: 0.5769 - val_accuracy: 0.8116
# Epoch 6/100
# 782/782 [==============================] - 12s 15ms/step - loss: 0.3065 - accuracy: 0.8923 - val_loss: 0.5123 - val_accuracy: 0.8286
# Epoch 7/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.2441 - accuracy: 0.9139 - val_loss: 0.5240 - val_accuracy: 0.8366
# Epoch 8/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0
100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.6820 - val_accuracy: 0.8738
# Epoch 60/100
# 782/782 [==============================] - 12s 15ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.6823 - val_accuracy: 0.8700
# Epoch 61/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.6604 - val_accuracy: 0.8772
# Epoch 62/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.6770 - val_accuracy: 0.8748
# Epoch 63/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.6792 - val_accuracy: 0.8732
# Epoch 64/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.6694 - val_accuracy: 0.8764
# Epoch 65/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.6968 - val_accuracy: 0.8754
# Epoch 66/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.6790 - val_accuracy: 0.8754
# Epoch 67/100
# 782/782 [==============================] - 12s 15ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.6753 - val_accuracy: 0.8770
# Epoch 68/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.7163 - val_accuracy: 0.8710
# Epoch 69/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.7496 - val_accuracy: 0.8670
# Epoch 70/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.7037 - val_accuracy: 0.8714
# Epoch 71/100
# 782/782 [==============================] - 12s 15ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.7022 - val_accuracy: 0.8678
# Epoch 72/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.6895 - val_accuracy: 0.8758
# Epoch 73/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.7022 - val_accuracy: 0.8732
# Epoch 74/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.7118 - val_accuracy: 0.8712
# Epoch 75/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.7617 - val_accuracy: 0.8706
# Epoch 76/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.7185 - val_accuracy: 0.8728
# Epoch 77/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.7422 - val_accuracy: 0.8714
# Epoch 78/100
# 782/782 [==============================] - 12s 15ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.7232 - val_accuracy: 0.8752
# Epoch 79/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.7253 - val_accuracy: 0.8736
# Epoch 80/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.7190 - val_accuracy: 0.8706
# Epoch 81/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.7664 - val_accuracy: 0.8702
# Epoch 82/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.7259 - val_accuracy: 0.8744
# Epoch 83/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.7130 - val_accuracy: 0.8748
# Epoch 84/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.7017 - val_accuracy: 0.8726
# Epoch 85/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.7185 - val_accuracy: 0.8726
# Epoch 86/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.7292 - val_accuracy: 0.8718
# Epoch 87/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.7103 - val_accuracy: 0.8706
# Epoch 88/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.7013 - val_accuracy: 0.8750
# Epoch 89/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.6992 - val_accuracy: 0.8752
# Epoch 90/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.7043 - val_accuracy: 0.8766
# Epoch 91/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.6990 - val_accuracy: 0.8778
# Epoch 92/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.7011 - val_accuracy: 0.8770
# Epoch 93/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.7180 - val_accuracy: 0.8752
# Epoch 94/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.6976 - val_accuracy: 0.8778
# Epoch 95/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.6831 - val_accuracy: 0.8810
# Epoch 96/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.7041 - val_accuracy: 0.8758
# Epoch 97/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.6708 - val_accuracy: 0.8788
# Epoch 98/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.6881 - val_accuracy: 0.8776
# Epoch 99/100
# 782/782 [==============================] - 12s 15ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.7031 - val_accuracy: 0.8734
# Epoch 100/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.6894 - val_accuracy: 0.8786
# Best model has test loss 0.004181844647973776 after 100 epochs
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)       3584
#
#  batch_normalization_7 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_8 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_9 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_10 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_11 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_12 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  batch_normalization_13 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,800,842
# Trainable params: 1,798,282
# Non-trainable params: 2,560
# _________________________________________________________________
# None

# %% [markdown]
# ## Train Poisoned Model
#
# - Select one of the generated configurations and train a poisoned model.
# - The poisoning uses an `injector` object which can be persisted for reproducibility. It will inject the backdoors/label noise into the same samples according to a seed. In our experiments, we worked with label noise poisoning.

# %%
from Applications.Poisoning.poison.poison_models import train_poisoned
from Applications.Poisoning.configs.demo.config import Config

poisoned_folder = model_folder/'budget-10000'/'seed-42'
poison_kwargs = Config.from_json(poisoned_folder/'poison_config.json')
train_kwargs = Config.from_json(poisoned_folder/'train_config.json')
train_poisoned(model_folder=poisoned_folder, poison_kwargs=poison_kwargs, train_kwargs=train_kwargs)
# Out:
# {'budget': 10000, 'seed': 42}
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 128)       3584
#
#  batch_normalization_14 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 128)       147584
#
#  batch_normalization_15 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_16 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_17 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_18 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_19 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 512)               1049088
#
#  batch_normalization_20 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,800,842
# Trainable params: 1,798,282
# Non-trainable params: 2,560
# _________________________________________________________________
# None
# Epoch 1/100
# 782/782 [==============================] - 13s 16ms/step - loss: 1.6807 - accuracy: 0.3941 - val_loss: 1.3258 - val_accuracy: 0.5014
# Epoch 2/100
# 782/782 [==============================] - 12s 16ms/step - loss: 1.2932 - accuracy: 0.5276 - val_loss: 1.0085 - val_accuracy: 0.6624
# Epoch 3/100
# 782/782 [==============================] - 12s 16ms/step - loss: 1.1149 - accuracy: 0.5878 - val_loss: 0.9125 - val_accuracy: 0.7098
# Epoch 4/100
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0027 - accuracy: 0.6245 - val_loss: 0.9086 - val_accuracy: 0.7042
# Epoch 5/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.9174 - accuracy: 0.6551 - val_loss: 0.8450 - val_accuracy: 0.7420
# Epoch 6/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.8386 - accuracy: 0.6788 - val_loss: 0.8006 - val_accuracy: 0.7386
# Epoch 7/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.7697 - accuracy: 0.7020 - val_loss: 0.7981 - val_accuracy: 0.7256
# Epoch 8/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.7060 - accuracy: 0.7245 - val_loss: 0.7993 - val_accuracy: 0.7328
# Epoch 9/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.6479 - accuracy: 0.7429 - val_loss: 0.7648 - val_accuracy: 0.7620
# Epoch 10/100
# 782/782 [==============================] - 12s 15ms/step - loss: 0.5892 - accuracy: 0.7668 - val_loss: 0.8050 - val_accuracy: 0.7406
# Epoch 11/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.5355 - accuracy: 0.7885 - val_loss: 0.8220 - val_accuracy: 0.7278
# Epoch 12/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.4803 - accuracy: 0.8099 - val_loss: 0.8864 - val_accuracy: 0.7258
# Epoch 13/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.4282 - accuracy: 0.8327 - val_loss: 0.8495 - val_accuracy: 0.7294
# Epoch 14/100
# 782/782 [==============================] - 12s 15ms/step - loss: 0.3856 - accuracy: 0.8510 - val_loss: 0.8378 - val_accuracy: 0.7364
# Epoch 15/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.3474 - accuracy: 0.8655 - val_loss: 0.8938 - val_accuracy: 0.7148
# Epoch 16/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.3319 - accuracy: 0.8716 - val_loss: 0.8993 - val_accuracy: 0.7212
# Epoch 17/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.
100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0275 - accuracy: 0.9905 - val_loss: 1.3027 - val_accuracy: 0.7476
# Epoch 76/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0287 - accuracy: 0.9903 - val_loss: 1.3128 - val_accuracy: 0.7356
# Epoch 77/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0281 - accuracy: 0.9905 - val_loss: 1.3112 - val_accuracy: 0.7416
# Epoch 78/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0250 - accuracy: 0.9918 - val_loss: 1.2994 - val_accuracy: 0.7360
# Epoch 79/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 1.2850 - val_accuracy: 0.7470
# Epoch 80/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0234 - accuracy: 0.9922 - val_loss: 1.2807 - val_accuracy: 0.7372
# Epoch 81/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0232 - accuracy: 0.9921 - val_loss: 1.2990 - val_accuracy: 0.7396
# Epoch 82/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 1.2787 - val_accuracy: 0.7412
# Epoch 83/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0221 - accuracy: 0.9922 - val_loss: 1.2996 - val_accuracy: 0.7412
# Epoch 84/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0223 - accuracy: 0.9922 - val_loss: 1.2748 - val_accuracy: 0.7448
# Epoch 85/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0232 - accuracy: 0.9921 - val_loss: 1.2976 - val_accuracy: 0.7292
# Epoch 86/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0230 - accuracy: 0.9926 - val_loss: 1.2855 - val_accuracy: 0.7454
# Epoch 87/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 1.2779 - val_accuracy: 0.7386
# Epoch 88/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0195 - accuracy: 0.9931 - val_loss: 1.2819 - val_accuracy: 0.7424
# Epoch 89/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 1.3060 - val_accuracy: 0.7324
# Epoch 90/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 1.3001 - val_accuracy: 0.7370
# Epoch 91/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0215 - accuracy: 0.9932 - val_loss: 1.2843 - val_accuracy: 0.7484
# Epoch 92/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 1.3270 - val_accuracy: 0.7430
# Epoch 93/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0232 - accuracy: 0.9920 - val_loss: 1.3741 - val_accuracy: 0.7354
# Epoch 94/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 1.3362 - val_accuracy: 0.7336
# Epoch 95/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0195 - accuracy: 0.9936 - val_loss: 1.3133 - val_accuracy: 0.7430
# Epoch 96/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0207 - accuracy: 0.9927 - val_loss: 1.3270 - val_accuracy: 0.7438
# Epoch 97/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0201 - accuracy: 0.9930 - val_loss: 1.3170 - val_accuracy: 0.7440
# Epoch 98/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 1.2992 - val_accuracy: 0.7466
# Epoch 99/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 1.3488 - val_accuracy: 0.7438
# Epoch 100/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 1.3031 - val_accuracy: 0.7404
# Best model has test loss 0.017946992069482803 after 99 epochs
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 32, 32, 128)       3584
#
#  batch_normalization_21 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 128)       147584
#
#  batch_normalization_22 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_9 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_23 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_24 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_25 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_26 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 4, 4, 128)         0
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 512)               1049088
#
#  batch_normalization_27 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_7 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,800,842
# Trainable params: 1,798,282
# Non-trainable params: 2,560
# _________________________________________________________________
# None

# %%
poisoned_weights = poisoned_folder/'best_model.hdf5'       # model that has been trained on poisoned data
fo_repaired_weights = poisoned_folder/'fo_repaired.hdf5'   # model weights after unlearning (first-order)
so_repaired_weights = poisoned_folder/'so_repaired.hdf5'   # model weights after unlearning (second-order)
injector_path = poisoned_folder/'injector.pkl'             # cached injector for reproducibility
clean_results = model_folder/'clean'/'train_results.json'  # path to reference results on clean dataset

# %% [markdown]
# ## Unlearning
#
# - Perform the first-order and second-order unlearning. The unlearning is wrapped in a function that
#     - loads the clean data, saves the original labels
#     - injects the poison (label noise)
#     - creates difference set Z using `injector.injected_idx`
#     - main unlearning happens in `Applications.Poisoning.unlearn.common.py:unlearn_update` and the thereby called `iter_approx_retraining` method
# - The variable naming follows the following ideas:
#     - `z_x`, `z_y`: features (x) and labels (y) in set `Z`
#     - `z_x_delta`, `z_y_delta`: changed features and labels (`z_x == z_x_delta` here and `z_y_delta` contains the original (fixed) labels)
# - A word about why iterative:
#     - The approximate retraining is configured to unlearn the desired changes in one step.
#     - To avoid putting a lot of redundant erroneous samples in the changing set `Z`, the iterative version
#         - takes a sub-sample (`prio_idx`) of `hvp_batch_size` in the delta set `Z`
#         - makes one unlearning step
#         - recalculates the delta set and focuses only on remaining errors
#     - The idea here is that similar to learning, it is better to work iteratively in batches since the approximation quality of the inverse hessian matrix decreases with the number of samples included (and the step size)

# %%
from Applications.Poisoning.unlearn.first_order import run_experiment as fo_experiment
from Applications.Poisoning.unlearn.second_order import run_experiment as so_experiment

fo_unlearn_kwargs = Config.from_json(poisoned_folder/'first-order'/'unlearn_config.json')
so_unlearn_kwargs = Config.from_json(poisoned_folder/'second-order'/'unlearn_config.json')

fo_experiment(poisoned_folder/'first-order', train_kwargs, poison_kwargs, fo_unlearn_kwargs)
so_experiment(poisoned_folder/'second-order', train_kwargs, poison_kwargs, so_unlearn_kwargs)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (BatchN  (None, 32, 32, 128)      512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_2 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,800,842
# Trainable params: 1,798,282
# Non-trainable params: 2,560
# _________________________________________________________________
# None
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)       3584
#
#  batch_normalization_7 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_8 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_9 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_10 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_11 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_12 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  batch_normalization_13 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,800,842
# Trainable params: 1,798,282
# Non-trainable params: 2,560
# _________________________________________________________________
# None
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (BatchN  (None, 32, 32, 128)      512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_2 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,800,842
# Trainable params: 1,798,282
# Non-trainable params: 2,560
# _________________________________________________________________
# None
# Early stopping at iteration 140. Update norm 1377764.8884277344 > [1376301.0076293945, 20]
# Early stopping at iteration 103. Update norm 1142491.3147583008 > [1119301.1447143555, 20]
# Early stopping at iteration 104. Update norm 1331326.412109375 > [1253077.9011230469, 20]
# Early stopping at iteration 91. Update norm 1876512.8565063477 > [1783461.2272949219, 20]
# Early stopping at iteration 96. Update norm 2043986.07421875 > [1881006.3835449219, 20]
# Early stopping at iteration 153. Update norm 1529187.5200195312 > [1477616.9118041992, 20]
# Early stopping at iteration 143. Update norm 1648820.8937988281 > [1612372.2330322266, 20]
# Early stopping at iteration 118. Update norm 1521663.7502441406 > [1448949.3966674805, 20]
# ../Applications/Poisoning/unlearn/common.py:209: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(10, 10))
# Early stopping at iteration 97. Update norm 1677492.5966186523 > [1547524.285583496, 20]
# Early stopping at iteration 81. Update norm 2440062.8809814453 > [2353708.4556884766, 20]
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)       3584
#
#  batch_normalization_7 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_8 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_9 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_10 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_11 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_12 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  batch_normalization_13 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,800,842
# Trainable params: 1,798,282
# Non-trainable params: 2,560
# _________________________________________________________________
# None

# %% [markdown]
# ## Visualizing the Results
#
# - To give some notion of how well the unlearning worked, we plot confusion matrices before and after unlearning.
# - This is just an example and not required for unlearning.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams

# figure size in inches optional
rcParams['figure.figsize'] = 11 ,8

# %%
cm_before = mpimg.imread(poisoned_folder/'first-order'/'cm'/'cm_unlearning_00.png')
cm_after = mpimg.imread(poisoned_folder/'first-order'/'cm'/'cm_unlearning_01.png')

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(cm_before)
ax[1].imshow(cm_after)
ax[0].grid(False)
ax[1].grid(False)
ax[0].tick_params(left=False, right=False , labelleft=False, labelbottom=False, bottom=False)
ax[1].tick_params(left=False, right=False , labelleft=False, labelbottom=False, bottom=False)

plt.show()

# %%
cm_before = mpimg.imread(poisoned_folder/'second-order'/'cm'/'cm_unlearning_00.png')
cm_after = mpimg.imread(poisoned_folder/'second-order'/'cm'/'cm_unlearning_01.png')

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(cm_before)
ax[1].imshow(cm_after)
ax[0].grid(False)
ax[1].grid(False)
ax[0].tick_params(left=False, right=False , labelleft=False, labelbottom=False, bottom=False)
ax[1].tick_params(left=False, right=False , labelleft=False, labelbottom=False, bottom=False)

plt.show()

# %% [markdown]
# As you can see, the second-order unlearning is able to fix some of the missing accuracy. However, it can also be observed that the unlearning is not exact in the non-convex setting.
